# %%
import cv2
from ultralytics import YOLO

# Load a small, fast YOLO model (COCO-pretrained)
# yolov8n, yolov8s, yolov8m, yolov8l, yolov8x 
model = YOLO("yolov8n.pt")

# Figure out the class IDs for the names we care about (mainly 'cup')
all_names = list(model.names.values())

wanted_names = all_names  # list ["cup", "person", "etc..."]
name_to_id = {name: idx for idx, name in model.names.items()}
wanted_ids = [name_to_id[n] for n in wanted_names if n in name_to_id]

# Open default webcam (try 1 or 2 if you have multiple cameras)
cap = cv2.VideoCapture(1)

if not cap.isOpened():
    raise RuntimeError("Could not open webcam.")

# Optional: set a smaller resolution for speed
cap.set(cv2.CAP_PROP_FRAME_WIDTH,  640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

print("Press 'q' to quit.")
while True:
    ok, frame = cap.read()
    if not ok:
        break

    # Inference on the current frame
    # - conf controls confidence threshold
    # - classes filters to just the IDs we want (e.g., cup)
    results = model(
        frame,
        conf=0.4,           # tweak 0.25–0.6 as needed
        classes=wanted_ids  # comment this line to see all classes
    )

    # Draw YOLO's nicely formatted annotations
    annotated = results[0].plot()

    # Show the frame
    cv2.imshow("YOLO – cups/mugs", annotated)

    # Quit on 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8x.pt to 'yolov8x.pt': 100% ━━━━━━━━━━━━ 130.5MB 5.4MB/s 24.1s24.0s<0.1ss
# Press 'q' to quit.
#
# 0: 480x640 1 person, 3 cups, 3 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 1288.5ms
# Speed: 25.1ms preprocess, 1288.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 2 cups, 2 tvs, 1 laptop, 1 mouse, 1413.1ms
# Speed: 4.2ms preprocess, 1413.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 2 cups, 2 tvs, 1 laptop, 1 mouse, 1 cell phone, 1243.5ms
# Speed: 2.1ms preprocess, 1243.5ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 chair, 2 tvs, 3 laptops, 1 mouse, 1234.0ms
# Speed: 1.9ms preprocess, 1234.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1267.7ms
# Speed: 2.0ms preprocess, 1267.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 1246.8ms
# Speed: 2.2ms preprocess, 1246.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 3 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 1257.5ms
# Speed: 1.6ms preprocess, 1257.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 2 tvs, 1 laptop, 1 mouse, 1 remote, 1 keyboard, 1 cell phone, 1298.4ms
# Speed: 3.5ms preprocess, 1298.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 chair, 4 tvs, 2 laptops, 1 mouse, 1 keyboard, 5 cell phones, 1489.1ms
# Speed: 2.4ms preprocess, 1489.1ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 3 tvs, 2 laptops, 2 mouses, 1 cell phone, 1408.4ms
# Speed: 4.0ms preprocess, 1408.4ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 cup, 2 tvs, 1 laptop, 2 mouses, 2 keyboards, 1 cell phone, 1375.7ms
# Speed: 3.5ms preprocess, 1375.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 cup, 1 chair, 1 tv, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 1 book, 1400.1ms
# Speed: 3.0ms preprocess, 1400.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1387.9ms
# Speed: 1.9ms preprocess, 1387.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1369.9ms
# Speed: 2.6ms preprocess, 1369.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 1 mouse, 1 cell phone, 1447.6ms
# Speed: 1.9ms preprocess, 1447.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
